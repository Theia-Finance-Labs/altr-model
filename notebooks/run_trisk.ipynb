# %%
from pathlib import Path
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
import pandas as pd
import os
# Out:
# [04/08/25 10:02:53] INFO     Using                                                                  ]8;id=595536;file:///Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=638827;file:///Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-pa
#                              ckages/kedro/framework/project/rich_logging.yml' as logging
#                              configuration.

# %%
os.environ["KEDRO_PACKAGE_NAME"] = "crispy_kedro"

# Since the notebook is in ./notebooks, set the project path to the parent directory
os.chdir(Path.cwd().parent)

metadata = bootstrap_project(project_path=Path.cwd())
# Out:
# [04/08/25 10:02:55] WARNING  /Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-pac ]8;id=878324;file:///Users/bertrandgallice/.pyenv/versions/3.10.12/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=956051;file:///Users/bertrandgallice/.pyenv/versions/3.10.12/lib/python3.10/warnings.py#109\109]8;;\
#                              kages/kedro/io/data_catalog.py:165: KedroDeprecationWarning:
#                              `DataCatalog` has been deprecated and will be replaced by
#                              `KedroDataCatalog`, in Kedro 1.0.0.Currently some `KedroDataCatalog`
#                              APIs have been retained for compatibility with `DataCatalog`,
#                              including the `datasets` property and the `get_datasets`,
#                              `_get_datasets`, `add`,` list`, `add_feed_dict`, and `shallow_copy`
#                              methods. These will be removed or replaced with updated alternatives
# ...

# %%
# Define your parameter overrides
extra_params = {
    "baseline_scenario": "NGFS2024_GCAM_CP",
    "target_scenario": "NGFS2024_GCAM_NZ2050",
    "scenario_geography": "Global",
    "shock_year": 2040,
    "forecast_horizon": 20,
    "discount_rate": 0.07,
    "growth_rate": 0.03,
    "asset_ids": [
        # "L100000104929",
        # "L100001004877",
        # "L100000829070",
        # "L100000909305",
        # "L100000401784",
        # "L100000832788",
        # "L100000101255",
        # "L100001004028",
        # "L100000917865",
        # "L100000814519",
        # "L100000820130",
        # "L100000820067",
        # "L100000808475",
        # "L603844",
        # "L100001010934",
        # "L100001003089"
    ]
}

# %%
# Cell 3: Create and run the Kedro session
with KedroSession.create(
    project_path=Path.cwd(),
    extra_params=extra_params
) as session:
    session.run(pipeline_name="trisk")
# Out:
# [04/08/25 10:02:55] INFO     Kedro project crispy-kedro                                              ]8;id=494731;file:///Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-packages/kedro/framework/session/session.py\session.py]8;;\:]8;id=433281;file:///Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-packages/kedro/framework/session/session.py#329\329]8;;\
# [04/08/25 10:02:56] WARNING  /Users/bertrandgallice/code/crispy-kedro/.venv/lib/python3.10/site-pac ]8;id=509866;file:///Users/bertrandgallice/.pyenv/versions/3.10.12/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=690445;file:///Users/bertrandgallice/.pyenv/versions/3.10.12/lib/python3.10/warnings.py#109\109]8;;\
#                              kages/kedro/io/data_catalog.py:165: KedroDeprecationWarning:
#                              `DataCatalog` has been deprecated and will be replaced by
#                              `KedroDataCatalog`, in Kedro 1.0.0.Currently some `KedroDataCatalog`
# ...

# %%
company_trajectories = pd.read_excel("data/08_reporting/companies_net_profits.xlsx")
company_trajectories
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                            company_id sector     technology  year  \
# 0    1a346e95a83e6225f4d2bb455eee1c52  Power        CoalCap  2023
# 1    1a346e95a83e6225f4d2bb455eee1c52  Power        CoalCap  2024
# 2    1a346e95a83e6225f4d2bb455eee1c52  Power        CoalCap  2025
# 3    1a346e95a83e6225f4d2bb455eee1c52  Power        CoalCap  2026
# 4    1a346e95a83e6225f4d2bb455eee1c52  Power        CoalCap  2027
# ..                                ...    ...            ...   ...
# 343  d228b814ff052635f7acb253fb5e6cd8  Power  RenewablesCap  2047
# 344  d228b814ff052635f7acb253fb5e6cd8  Power  RenewablesCap  2048
# 345  d228b814ff052635f7acb253fb5e6cd8  Power  RenewablesCap  2049
# 346  d228b814ff052635f7acb253fb5e6cd8  Power  RenewablesCap  2050
# 347  d228b814ff052635f7acb253fb5e6cd8  Power  RenewablesCap  2051
#
# ...

# %%
assets_input_data = pd.read_excel("data/08_reporting/traj_assets_raw_truncated.xlsx")
assets_input_data
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           asset_id sector technology  year  asset_trajectory
# 0    L100000101255  Power    CoalCap  2023             400.0
# 1    L100000101255  Power    CoalCap  2024             400.0
# 2    L100000101255  Power    CoalCap  2025             400.0
# 3    L100000101255  Power    CoalCap  2026             400.0
# 4    L100000101255  Power    CoalCap  2027             400.0
# ..             ...    ...        ...   ...               ...
# 331        L603844  Power   HydroCap  2039             177.0
# 332        L603844  Power   HydroCap  2040             177.0
# 333        L603844  Power   HydroCap  2041             177.0
# 334        L603844  Power   HydroCap  2042             177.0
# 335        L603844  Power   HydroCap  2043             177.0
#
# [336 rows x 5 columns]
